# %%
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import numpy as np
import random
from tensorflow.keras.layers import Conv2D,MaxPooling2D

# %% [markdown]
# # Load Dataset

# %%
    X_train = np.loadtxt(r'C:\Users\admin\Downloads\input.csv',delimiter = ',')
    y_train = np.loadtxt(r'C:\Users\admin\Downloads\labels.csv',delimiter = ',')

    X_test = np.loadtxt(r'C:\Users\admin\Downloads\input_test.csv',delimiter = ',')
    y_test = np.loadtxt(r'C:\Users\admin\Downloads\labels_test.csv',delimiter = ',')

    X_train = X_train/255.0
    X_test = X_test/255.0

# %%
# Reshape data
num_samples_train = len(X_train)
num_samples_test = len(X_test)
X_train = X_train.reshape(num_samples_train, 100, 100, 3)
y_train = y_train.reshape(num_samples_train, 1)
X_test = X_test.reshape(num_samples_test, 100, 100, 3)
y_test = y_test.reshape(num_samples_test, 1)

# %%
print('shape of X_train',X_train.shape)
print('shape of y_train',y_train.shape)
print('shape of X_test',X_test.shape)
print('shape of y_test',y_test.shape)
# Out:
# shape of X_train (2000, 100, 100, 3)
# shape of y_train (2000, 1)
# shape of X_test (400, 100, 100, 3)
# shape of y_test (400, 1)

# %%
X_train[1,:]
# Out:
# array([[[0.51372549, 0.50196078, 0.52941176],
#         [0.62745098, 0.61568627, 0.64313725],
#         [0.77647059, 0.75294118, 0.8       ],
#         ...,
#         [0.98039216, 0.97647059, 0.96862745],
#         [1.        , 1.        , 0.99215686],
#         [0.98039216, 0.97647059, 0.96078431]],
#
#        [[0.54901961, 0.5372549 , 0.56470588],
#         [0.49803922, 0.48627451, 0.51372549],
#         [0.47058824, 0.44705882, 0.48627451],
#         ...,
#         [0.98431373, 0.99215686, 0.98823529],
#         [0.99607843, 1.        , 0.99215686],
#         [0.99607843, 1.        , 0.98431373]],
#
#        [[0.8       , 0.79215686, 0.81176471],
#         [0.73333333, 0.7254902 , 0.74509804],
#         [0.57647059, 0.55686275, 0.58039216],
#         ...,
#         [0.97647059, 1.        , 1.        ],
#         [0.93333333, 0.96862745, 0.94901961],
#         [0.90980392, 0.94509804, 0.9254902 ]],
#
#        ...,
#
#        [[0.68235294, 0.71372549, 0.76470588],
#         [0.6745098 , 0.70588235, 0.75686275],
#         [0.69803922, 0.72941176, 0.77254902],
#         ...,
#         [0.34117647, 0.44705882, 0.38039216],
#         [0.29411765, 0.38823529, 0.3254902 ],
#         [0.31372549, 0.41176471, 0.3372549 ]],
#
#        [[0.65098039, 0.67843137, 0.74117647],
#         [0.64313725, 0.6745098 , 0.7254902 ],
#         [0.6745098 , 0.70588235, 0.75686275],
#         ...,
#         [0.30588235, 0.41568627, 0.32941176],
#         [0.28235294, 0.38039216, 0.29803922],
#         [0.30196078, 0.4       , 0.31764706]],
#
#        [[0.67843137, 0.70588235, 0.76862745],
#         [0.6745098 , 0.70196078, 0.76470588],
#         [0.68235294, 0.71372549, 0.76470588],
#         ...,
#         [0.24705882, 0.35686275, 0.27058824],
#         [0.24313725, 0.34117647, 0.25490196],
#         [0.27843137, 0.37647059, 0.29019608]]])

# %%
idx = random.randint(0, len(X_train) - 1)
plt.imshow(X_train[idx])
plt.show()

# %% [markdown]
# # Model

# %%
# Define the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
#     Flatten(),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid'),
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       1 # Define the model
#       2 model = Sequential([
#       3     Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
#       4     MaxPooling2D((2, 2)),
#       5     Conv2D(32, (3, 3), activation='relu'),
#       6     MaxPooling2D((2, 2)),
#       7 #     Flatten(),
# ----> 8     Dense(64, activation='relu'),
#       9     Dense(1, activation='sigmoid'),
#      10 ])
#
# NameError: name 'Dense' is not defined

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), activation = 'relu',input_shape = (100, 100, 3)),)
model.add( MaxPooling2D((2,2)))

model.add(Conv2D(32, (3,3), activation='relu'))
model.add( MaxPooling2D((2,2)))

model.add( Dense(64, activation = 'relu'))
model.add( Dense(1,activation = 'sigmoid'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 9
#       6 model.add(Conv2D(32, (3,3), activation='relu'))
#       7 model.add( MaxPooling2D((2,2)))
# ----> 9 model.add( Dense(64, activation = 'relu'))
#      10 model.add( Dense(1,activation = 'sigmoid'))
#
# NameError: name 'Dense' is not defined

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=5, batch_size=64)

# %%
model.evaluate(X_test,y_test)

# %% [markdown]
# # Making Predictions

# %%
idx2 = random.randint(0,len(y_test))
plt.imshow(X_test[idx2,:])
plt.show()

y_pred = model.predict(X_test[idx2,:].reshape(1,100,100,3))
print(y_pred)

if(y_pred  == 0 ):
    pred = 'dog'
else:
    pred = 'cat'
    
print ("our model says it is a :",pred)

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Load data
X_train = np.loadtxt(r'C:\Users\admin\Downloads\input.csv', delimiter=',')
y_train = np.loadtxt(r'C:\Users\admin\Downloads\labels.csv', delimiter=',')

X_test = np.loadtxt(r'C:\Users\admin\Downloads\input_test.csv', delimiter=',')
y_test = np.loadtxt(r'C:\Users\admin\Downloads\labels_test.csv', delimiter=',')

# Normalize data
X_train = X_train / 300.0
X_test = X_test / 300.0

# Reshape data
num_samples_train = len(X_train)
num_samples_test = len(X_test)
X_train = X_train.reshape(num_samples_train, 100, 100, 3)
y_train = y_train.reshape(num_samples_train, 1)
X_test = X_test.reshape(num_samples_test, 100, 100, 3)
y_test = y_test.reshape(num_samples_test, 1)

# Print shapes to verify
print('Shape of X_train:', X_train.shape)
print('Shape of y_train:', y_train.shape)
print('Shape of X_test:', X_test.shape)
print('Shape of y_test:', y_test.shape)

# Display a random image from the training set
idx = random.randint(0, len(X_train) - 1)
plt.imshow(X_train[idx])
plt.show()

# Define the model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=7, batch_size=60)
# Out:
# Shape of X_train: (2000, 100, 100, 3)
# Shape of y_train: (2000, 1)
# Shape of X_test: (400, 100, 100, 3)
# Shape of y_test: (400, 1)
# Epoch 1/7
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.4965 - loss: 0.7107
# Epoch 2/7
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.5352 - loss: 0.6794
# Epoch 3/7
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.6801 - loss: 0.6097
# Epoch 4/7
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.7198 - loss: 0.5346
# Epoch 5/7
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 183ms/step - accuracy: 0.7628 - loss: 0.4927
# Epoch 6/7
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.7992 - loss: 0.4352
# Epoch 7/7
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 184ms/step - accuracy: 0.8356 - loss: 0.3942

# %%
model.evaluate(X_test,y_test)

idx2 = random.randint(0,len(y_test))
plt.imshow(X_test[idx2,:])
plt.show()

y_pred = model.predict(X_test[idx2,:].reshape(1,100,100,3))
print(y_pred)

if y_pred <= 0.5:
    pred = 'dog'
else:
    pred = 'cat'
    
print ("our model says it is a :",pred)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5749 - loss: 0.8929
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# [[0.2996019]]
# our model says it is a : dog
